# %% [markdown]
# # 4D SU(2) validated RG — project index
#
# このファイルは旧パスとの互換性を保つための**案内専用**ノートブックです。計算はここでは実行しません。すべて同じ `validated_4d_su2_rg_codex_bundle` プロジェクトで、次の順序に従ってください。
#
# 1. `notebooks/00_project_setup.ipynb` — pytest の導入と環境確認
# 2. `notebooks/10_m0_accepted_audit.ipynb` — 受理済み M0 の読み取り専用再監査
# 3. `notebooks/20_m1_exact_2d.ipynb` — M1 exact 2D benchmark の実装・再開・報告
# 4. `notebooks/30_m2_armillary.ipynb` — M1 受理確認後の M2 ゲート
# 5. `notebooks/40_m3_gpu_triad_atrg.ipynb` — M2 受理確認後の M3 ゲート
# 6. `notebooks/50_m4_derivatives.ipynb` — M3 受理確認後の M4 ゲート
# 7. `notebooks/60_m5_one_step_certificate.ipynb` — M4 受理確認後の M5 ゲート
# 8. `notebooks/70_m6_multistep_certificate.ipynb` — M5 受理確認後の M6 ゲート
#
# M2–M6 は、直前段階が実環境で受理されるまで数値実装を開始しない fail-closed ノートブックです。詳しい手順はルートの `README.md` を参照してください。
