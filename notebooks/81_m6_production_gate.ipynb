# %% [markdown]
# # 81 — Campaign C production M6 gate
#
# 設計書 §19。
#
# Production M6 は次をすべて要求する。
#
# - `certification_status == ONE_STEP_CERTIFIED`
# - `all_obligations_closed`
# - `independent_verifier_pass`
# - `q_cert_upper < 1`
#
# `NOT_CERTIFIED` parent での multistep は `mode=diagnostic_fixture` のみ。

# %%
from src.m5_closure_schema import NOTEBOOKS, ONE_STEP_CERTIFIED
print('This notebook:', NOTEBOOKS['M6'])
print('Required parent certification:', ONE_STEP_CERTIFIED)
raise NotImplementedError(
    'PR-5 M6 production gate not enabled until ONE_STEP_CERTIFIED M5 exists.'
)
