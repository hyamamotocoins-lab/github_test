# %% [markdown]
# # 79 — Campaign C S3/S4: basis variation and tails (M4-R)
#
# 設計書 §§12–14, 16。
#
# **前提:** notebook 78 の M3-R が residual/gap certificate を持つ。
#
# - basis variation (O2b)
# - representation tail (O3)
# - channel completeness / cutoff channel tail (O4)
# - 旧 `-v2` の closed 4義務も **再評価**（コピー禁止）

# %%
from src.m5_closure_schema import NOTEBOOKS, OPEN_OBLIGATION_IDS
print('This notebook:', NOTEBOOKS['S3_S4'])
print('Open obligation targets:', OPEN_OBLIGATION_IDS)
raise NotImplementedError(
    'PR-3/PR-4 required: basis_variation_certificate, representation_tail_certificate, '
    'channel_completeness. Do not write production M5_acceptance.'
)
